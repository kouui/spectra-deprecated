# %% [markdown]
# # Classical radiation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # implementation

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import sympy
from sympy.vector import CoordSys3D

# %%
from sympy.physics.units import speed_of_light
c = speed_of_light

# %%
C = CoordSys3D("C")

# %%
C = CoordSys3D("C")
t = sympy.Symbols("t")
r = C.x * C.i + C.y * C.j + C.z * C.k
rs =
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-2582166665aa> in <module>
# ----> 1 C = sp.vector.CoordSys2D
#
# AttributeError: module 'sympy' has no attribute 'vector'
