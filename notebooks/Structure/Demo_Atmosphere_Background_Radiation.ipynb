# %%
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append("../../")

# %load_ext autoreload
# %autoreload 2

from src.Structure import AtmosphereCls

# %% [markdown]
# ---

# %%
slab0d = AtmosphereCls.AtmosphereC0d()
slab0d.read_BackRad_QS()

# %%
fig ,ax = plt.subplots(1,1, figsize=(6,2), dpi=150)

#ax.plot(slab0d.BackRad_wav, slab0d.BackRad_int, "k-", linewidth=0.7, label="vacuum")
ax.plot(slab0d.BackRadAir_wav, slab0d.BackRadAir_int, "r-", linewidth=0.7, label="air")

ax.set_xlabel("Wavelength[$\AA$]")
ax.set_ylabel("Intensity[$erg/cm^{2}/Sr/cm/s$]")

#ax.set_yscale("log")
ax.set_xlim(5245, 5255)
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ---

# %%
from PIL import Image
import os
import numpy as np
im = Image.open( os.path.abspath('/Users/liu/Desktop/test2/test2000001.tif') )
im.show()
imarray = np.array(im)
prof = imarray[500:503,:].mean(axis=0)

# %%
fig ,ax = plt.subplots(1,1, figsize=(6,5), dpi=150)

#ax.plot(slab0d.BackRad_wav, slab0d.BackRad_int, "k-", linewidth=0.7, label="vacuum")
ax.plot(slab0d.BackRadAir_wav, slab0d.BackRadAir_int / 1.2E14, "r-", linewidth=0.7, label="air")

ax.set_xlabel("Wavelength[$\AA$]")
ax.set_ylabel("Intensity[$erg/cm^{2}/Sr/cm/s$]")

#ax.set_yscale("log")
#k = 5240
#ax[0].set_xlim(k, k+17)
k = 5243.5 - 0.3
ax.set_xlim(k, k+17.5)
ax.legend(loc="upper right")

ax1 = ax.twiny()
ax1.plot(prof / 120)

plt.show()
